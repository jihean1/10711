# %% [markdown]
# <a href="https://colab.research.google.com/github/jihean1/10711/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('재미있는 프로그래밍')
print(3+7)
print(10,20,30,'정보','프로그래밍')
# Out:
# 재미있는 프로그래밍
# 10
# 10 20 30 정보 프로그래밍

# %%
print('한양과학기술고등학교','1학년','송지현')
# Out:
# 한양과학기술고등학교 1학년 송지현

# %%
print(f'현재 온도는 {20}도 입니다.')
# Out:
# 현재 온도는 20도 입니다.

# %%
print('현재 온도는 {}도입니다.''.format(20)')
# Out:
# 현재 온도는 {}도입니다..format(20)

# %%
a= 20
b=50
print(f'현재 온도는 {a}도,습도는 {b}%입니다')
# Out:
# 현재 온도는 20도,습도는 50%입니다

# %%
print(f'직각은{c}도,원주율은{d:0.2f}입니다.')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7347/3051071414.py in <cell line: 0>()
# ----> 1 print(f'직각은{c}도,원주율은{d:0.2f}입니다.')
#
# NameError: name 'c' is not defined
